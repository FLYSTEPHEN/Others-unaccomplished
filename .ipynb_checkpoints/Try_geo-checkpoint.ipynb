# %%
locations = list(df_code_country_data_j['country_code'])
text = list(df_code_country_data_j['country'])
z = list(df_code_country_data_j['count'])
ztitle = 'amount'
title = 'Map1: Global Data Journalist Distribution<br>Source:\
                <a href="http://jplusplus.github.io/global-directory/">\
                Global Data Journalist Directory</a>'
filename = title.split('<br>')[0]

paint_world_map_choropleth(title,locations,z,ztitle,filename)

# %%
import pandas as pd
from geopy.geocoders import Nominatim
import time
geolocator = Nominatim(user_agent="my-application",)
location=geolocator.reverse(40.274463,74.843670,language='en')
location.raw
# list_coordinate = []
# for i in df_selected_jobs["Location"]:
#     list_coordinate.append(geolocator.geocode(i))
#     time.sleep(1)
# Out:
# /Users/chao/venv/lib/python3.7/site-packages/geopy/point.py:180: UserWarning: A single number has been passed to the Point constructor. This is probably a mistake, because constructing a Point with just a latitude seems senseless. If this is exactly what was meant, then pass the zero longitude explicitly to get rid of this warning.
#   UserWarning)
# {'place_id': '124812190',
#  'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#  'osm_type': 'way',
#  'osm_id': '207381253',
#  'lat': '40.2764054',
#  'lon': '-0.000583',
#  'display_name': 'Colada del Rotador, Les Deveses, Sierra Engarcerán, la Plana Alta, Castelló / Castellón, Valencian Community, Spain',
#  'address': {'road': 'Colada del Rotador',
#   'suburb': 'Les Deveses',
#   'village': 'Sierra Engarcerán',
#   'region': 'la Plana Alta',
#   'county': 'Castelló / Castellón',
#   'state': 'Valencian Community',
#   'country': 'Spain',
#   'country_code': 'es'},
#  'boundingbox': ['40.2702735', '40.2867927', '-0.0143597', '0.0080522']}

# %%
import pandas as pd
from geopy.geocoders import Nominatim
import time
list_raw=[]
geolocator = Nominatim(user_agent="my-application")
df_dj = pd.read_csv("reference/journalists-data.csv",
            names=['name','agency','location','github'])
for i in df_dj['location']:
    location=geolocator.geocode(i, language='en',timeout=60)
    list_raw.append(location.raw)
    time.sleep(2)
df = pd.DataFrame(list_raw)
df.to_csv('geopy-raw.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-431c836a0275> in <module>()
#       5 geolocator = Nominatim(user_agent="my-application")
#       6 df_dj = pd.read_csv("reference/journalists-data.csv",
# ----> 7             names=['name','agency','location','github'])
#       8 for i in df_dj['location']:
#       9     location=geolocator.geocode(i, language='en',timeout=60)
#
# ~/venv/lib/python3.7/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, doublequote, delim_whitespace, low_memory, memory_map, float_precision)
#     676                     skip_blank_lines=skip_blank_lines)
#     677
# --> 678         return _read(filepath_or_buffer, kwds)
#     679
#     680     parser_f.__name__ = name
#
# ~/venv/lib/python3.7/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     438
#     439     # Create the parser.
# --> 440     parser = TextFileReader(filepath_or_buffer, **kwds)
#     441
#     442     if chunksize or iterator:
#
# ~/venv/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     785             self.options['has_index_names'] = kwds['has_index_names']
#     786
# --> 787         self._make_engine(self.engine)
#     788
#     789     def close(self):
#
# ~/venv/lib/python3.7/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1012     def _make_engine(self, engine='c'):
#    1013         if engine == 'c':
# -> 1014             self._engine = CParserWrapper(self.f, **self.options)
#    1015         else:
#    1016             if engine == 'python':
#
# ~/venv/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1706         kwds['usecols'] = self.usecols
#    1707
# -> 1708         self._reader = parsers.TextReader(src, **kwds)
#    1709
#    1710         passed_names = self.names is None
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: File b'reference/journalists-data.csv' does not exist

# %%
import plotly.plotly as py
import pandas as pd

df_1 = pd.read_csv('geopy-raw.csv')  #geopy-raw.csv是上一cell中导出的记者地址原始数据
df_2 = pd.read_csv('reference/country2code.csv'
                   ,names=['COUNTRY','CODE'])  #reference/country2code.csv是转换器文件
list_country = [i.split(', ')[-1] for i in df_1['display_name']]  #獲取地址中的country
dict_country2code = df_2.set_index('COUNTRY').T.to_dict('list')  #country2code的dataframe轉化為字典
list_code = [dict_country2code[i][0] for i in list_country]  #将所有记者的country转化为code
dict_count = {}
for m in list_code:  #计数code
    dict_count[m] = list_code.count(m) #根據country2code，country轉化為code
df_merge_1 = pd.DataFrame(dict_count, index=['data']).T
#因为计数结果未包含所有country，所以将计数结果转化为dataframe，准备合并到完整的country表上
df_merge_2 = pd.read_csv('reference/code&country.csv',names=['code','country'])  #这是完整的country表
df_code_country_data = df_merge_2.join(df_merge_1, on='code').fillna(0)  #将数据合并到完整的country表上，填充NaN
df_merge_1
df_merge_0

# %%
# !pip install geopandas
# Out:
# Collecting geopandas
#   Using cached https://files.pythonhosted.org/packages/24/11/d77c157c16909bd77557d00798b05a5b6615ed60acb5900fbe6a65d35e93/geopandas-0.4.0-py2.py3-none-any.whl
# Requirement already satisfied: shapely in /Users/chao/venv/lib/python3.7/site-packages (from geopandas) (1.6.4.post2)
# Requirement already satisfied: pandas in /Users/chao/venv/lib/python3.7/site-packages (from geopandas) (0.23.4)
# Requirement already satisfied: pyproj in /Users/chao/venv/lib/python3.7/site-packages (from geopandas) (1.9.5.1)
# Requirement already satisfied: fiona in /Users/chao/venv/lib/python3.7/site-packages (from geopandas) (1.8.1)
# Requirement already satisfied: numpy>=1.9.0 in /Users/chao/venv/lib/python3.7/site-packages (from pandas->geopandas) (1.15.1)
# Requirement already satisfied: python-dateutil>=2.5.0 in /Users/chao/venv/lib/python3.7/site-packages (from pandas->geopandas) (2.7.3)
# Requirement already satisfied: pytz>=2011k in /Users/chao/venv/lib/python3.7/site-packages (from pandas->geopandas) (2018.5)
# Requirement already satisfied: click<8,>=4.0 in /Users/chao/venv/lib/python3.7/site-packages (from fiona->geopandas) (7.0)
# Requirement already satisfied: six>=1.7 in /Users/chao/venv/lib/python3.7/site-packages (from fiona->geopandas) (1.11.0)
# Requirement already satisfied: munch in /Users/chao/venv/lib/python3.7/site-packages (from fiona->geopandas) (2.3.2)
# Requirement already satisfied: cligj>=0.5 in /Users/chao/venv/lib/python3.7/site-packages (from fiona->geopandas) (0.5.0)
# Requirement already satisfied: click-plugins>=1.0 in /Users/chao/venv/lib/python3.7/site-packages (from fiona->geopandas) (1.0.4)
# Requirement already satisfied: attrs>=17 in /Users/chao/venv/lib/python3.7/site-packages (from fiona->geopandas) (18.2.0)
# Installing collected packages: geopandas
# Successfully installed geopandas-0.4.0

# %%
from IPython.display import IFrame
import plotly.plotly as py
import plotly.figure_factory as ff

import numpy as np
import pandas as pd

df_sample = pd.read_csv('https://raw.githubusercontent.com/plotly/datasets/master/laucnty16.csv')
df_sample['State FIPS Code'] = df_sample['State FIPS Code'].apply(lambda x: str(x).zfill(2))
df_sample['County FIPS Code'] = df_sample['County FIPS Code'].apply(lambda x: str(x).zfill(3))
df_sample['FIPS'] = df_sample['State FIPS Code'] + df_sample['County FIPS Code']

colorscale = ["#f7fbff","#ebf3fb","#deebf7","#d2e3f3","#c6dbef","#b3d2e9","#9ecae1",
              "#85bcdb","#6baed6","#57a0ce","#4292c6","#3082be","#2171b5","#1361a9",
              "#08519c","#0b4083","#08306b"]
endpts = list(np.linspace(1, 12, len(colorscale) - 1))
fips = df_sample['FIPS'].tolist()
values = df_sample['Unemployment Rate (%)'].tolist()

fig = ff.create_choropleth(
    fips=fips, values=values,
    binning_endpoints=endpts,
    colorscale=colorscale,
    show_state_data=False,
    show_hover=True, centroid_marker={'opacity': 0},
    asp=2.9, title='USA by Unemployment %',
    legend_title='% unemployed',
)
# Out:
# /Users/chao/geovenv/lib/python3.7/site-packages/pandas/core/frame.py:6211: FutureWarning:
#
# Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
# The draw time for this plot will be slow for clients without much RAM.
# /Users/chao/geovenv/lib/python3.7/site-packages/plotly/api/v1/clientresp.py:40: UserWarning:
#
# Estimated Draw Time Slow
#
# /Users/chao/geovenv/lib/python3.7/site-packages/IPython/core/display.py:689: UserWarning:
#
# Consider using IPython.display.IFrame instead
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-a4e4981301ad> in <module>
#      27     legend_title='% unemployed',
#      28 )
# ---> 29 display(IFrame(py.iplot(fig, filename='choropleth_full_usa')),400,400)
#
# TypeError: __init__() missing 2 required positional arguments: 'width' and 'height'

# %%
display(IFrame(py.iplot(fig, filename='choropleth_full_usa'),width=400,height=400))
# Out:
# The draw time for this plot will be slow for clients without much RAM.
#         <iframe
#             width="400"
#             height="400"
#             src="<plotly.tools.PlotlyDisplay object>"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
# !pip install pyproj
# Out:
# Collecting pyproj
#   Using cached https://files.pythonhosted.org/packages/29/72/5c1888c4948a0c7b736d10e0f0f69966e7c0874a660222ed0a2c2c6daa9f/pyproj-1.9.5.1.tar.gz
# Installing collected packages: pyproj
#   Running setup.py install for pyproj ... error
#     Complete output from command /Users/chao/venv/bin/python3.7 -u -c "import setuptools, tokenize;__file__='/private/var/folders/h3/mrhx5cg11xn7w4yzstp8sx7w0000gn/T/pip-install-a07gnxom/pyproj/setup.py';f=getattr(tokenize, 'open', open)(__file__);code=f.read().replace('\r\n', '\n');f.close();exec(compile(code, __file__, 'exec'))" install --record /private/var/folders/h3/mrhx5cg11xn7w4yzstp8sx7w0000gn/T/pip-record-78e6_rol/install-record.txt --single-version-externally-managed --compile --install-headers /Users/chao/venv/include/site/python3.7/pyproj:
#     using bundled proj4..
#     nad2bin.c:362:21: warning: comparison of integers of different signs: 'size_t' (aka 'unsigned long') and 'int' [-Wsign-compare]
#                         != 4 * ct.lim.lam )
#                         ^  ~~~~~~~~~~~~~~
#     1 warning generated.
#     executing /private/var/folders/h3/mrhx5cg11xn7w4yzstp8sx7w0000gn/T/pip-install-a07gnxom/pyproj/nad2bin lib/pyproj/data/TN < datumgrid/TN.llaOutput Binary File Format: ctable2
#     executing /private/var/folders/h3/mrhx5cg11xn7w4yzstp8sx7w0000gn/T/pip-install-a07gnxom/pyproj/nad2bin lib/pyproj/data/stlrnc < datumgrid/stlrnc.llaOutput Binary File Format: ctable2
#     executing /private/var/folders/h3/mrhx5cg11xn7w4yzstp8sx7w0000gn/T/pip-install-a07gnxom/pyproj/nad2bin lib/pyproj/data/hawaii < datumgrid/hawaii.llaOutput Binary File Format: ctable2
#     executing /private/var/folders/h3/mrhx5cg11xn7w4yzstp8sx7w0000gn/T/pip-install-a07gnxom/pyproj/nad2bin lib/pyproj/data/null < datumgrid/null.llaOutput Binary File Format: ctable2
#     executing /private/var/folders/h3/mrhx5cg11xn7w4yzstp8sx7w0000gn/T/pip-install-a07gnxom/pyproj/nad2bin lib/pyproj/data/FL < datumgrid/FL.llaOutput Binary File Format: ctable2
#     executing /private/var/folders/h3/mrhx5cg11xn7w4yzstp8sx7w0000gn/T/pip-install-a07gnxom/pyproj/nad2bin lib/pyproj/data/stpaul < datumgrid/stpaul.llaOutput Binary File Format: ctable2
#     executing /private/var/folders/h3/mrhx5cg11xn7w4yzstp8sx7w0000gn/T/pip-install-a07gnxom/pyproj/nad2bin lib/pyproj/data/conus < datumgrid/conus.llaOutput Binary File Format: ctable2
#     executing /private/var/folders/h3/mrhx5cg11xn7w4yzstp8sx7w0000gn/T/pip-install-a07gnxom/pyproj/nad2bin lib/pyproj/data/prvi < datumgrid/prvi.llaOutput Binary File Format: ctable2
#     executing /private/var/folders/h3/mrhx5cg11xn7w4yzstp8sx7w0000gn/T/pip-install-a07gnxom/pyproj/nad2bin lib/pyproj/data/MD < datumgrid/MD.llaOutput Binary File Format: ctable2
#     executing /private/var/folders/h3/mrhx5cg11xn7w4yzstp8sx7w0000gn/T/pip-install-a07gnxom/pyproj/nad2bin lib/pyproj/data/WI < datumgrid/WI.llaOutput Binary File Format: ctable2
#     executing /private/var/folders/h3/mrhx5cg11xn7w4yzstp8sx7w0000gn/T/pip-install-a07gnxom/pyproj/nad2bin lib/pyproj/data/stgeorge < datumgrid/stgeorge.llaOutput Binary File Format: ctable2
#     executing /private/var/folders/h3/mrhx5cg11xn7w4yzstp8sx7w0000gn/T/pip-install-a07gnxom/pyproj/nad2bin lib/pyproj/data/alaska < datumgrid/alaska.llaOutput Binary File Format: ctable2
#     executing /private/var/folders/h3/mrhx5cg11xn7w4yzstp8sx7w0000gn/T/pip-install-a07gnxom/pyproj/nad2bin lib/pyproj/data/WO < datumgrid/WO.llaOutput Binary File Format: ctable2
#     running install
#     running build
#     running build_py
#     creating build
#     creating build/lib.macosx-10.13-x86_64-3.7
#     creating build/lib.macosx-10.13-x86_64-3.7/pyproj
#     copying lib/pyproj/__init__.py -> build/lib.macosx-10.13-x86_64-3.7/pyproj
#     copying lib/pyproj/datadir.py -> build/lib.macosx-10.13-x86_64-3.7/pyproj
#     creating build/lib.macosx-10.13-x86_64-3.7/pyproj/data
#     copying lib/pyproj/data/test27 -> build/lib.macosx-10.13-x86_64-3.7/pyproj/data
#     copying lib/pyproj/data/esri.extra -> build/lib.macosx-10.13-x86_64-3.7/pyproj/data
#     copying lib/pyproj/data/testvarious -> build/lib.macosx-10.13-x86_64-3.7/pyproj/data
#     copying lib/pyproj/data/alaska -> build/lib.macosx-10.13-x86_64-3.7/pyproj/data
#     copying lib/pyproj/data/pj_out27.dist -> build/lib.macosx-10.13-x86_64-3.7/pyproj/data
#     copying lib/pyproj/data/ntv2_out.dist -> build/lib.macosx-10.13-x86_64-3.7/pyproj/data
#     copying lib/pyproj/data/ntf_r93.gsb -> build/lib.macosx-10.13-x86_64-3.7/pyproj/data
#     copying lib/pyproj/data/conus -> build/lib.macosx-10.13-x86_64-3.7/pyproj/data
#     copying lib/pyproj/data/stpaul -> build/lib.macosx-10.13-x86_64-3.7/pyproj/data
#     copying lib/pyproj/data/IGNF -> build/lib.macosx-10.13-x86_64-3.7/pyproj/data
#     copying lib/pyproj/data/nad83 -> build/lib.macosx-10.13-x86_64-3.7/pyproj/data
#     copying lib/pyproj/data/esri -> build/lib.macosx-10.13-x86_64-3.7/pyproj/data
#     copying lib/pyproj/data/prvi -> build/lib.macosx-10.13-x86_64-3.7/pyproj/data
#     copying lib/pyproj/data/pj_out83.dist -> build/lib.macosx-10.13-x86_64-3.7/pyproj/data
#     copying lib/pyproj/data/testntv2 -> build/lib.macosx-10.13-x86_64-3.7/pyproj/data
#     copying lib/pyproj/data/FL -> build/lib.macosx-10.13-x86_64-3.7/pyproj/data
#     copying lib/pyproj/data/world -> build/lib.macosx-10.13-x86_64-3.7/pyproj/data
#     copying lib/pyproj/data/README -> build/lib.macosx-10.13-x86_64-3.7/pyproj/data
#     copying lib/pyproj/data/test83 -> build/lib.macosx-10.13-x86_64-3.7/pyproj/data
#     copying lib/pyproj/data/nzgd2kgrid0005.gsb -> build/lib.macosx-10.13-x86_64-3.7/pyproj/data
#     copying lib/pyproj/data/nad.lst -> build/lib.macosx-10.13-x86_64-3.7/pyproj/data
#     copying lib/pyproj/data/null -> build/lib.macosx-10.13-x86_64-3.7/pyproj/data
#     copying lib/pyproj/data/ntv1_can.dat -> build/lib.macosx-10.13-x86_64-3.7/pyproj/data
#     copying lib/pyproj/data/td_out.dist -> build/lib.macosx-10.13-x86_64-3.7/pyproj/data
#     copying lib/pyproj/data/MD -> build/lib.macosx-10.13-x86_64-3.7/pyproj/data
#     copying lib/pyproj/data/proj_def.dat -> build/lib.macosx-10.13-x86_64-3.7/pyproj/data
#     copying lib/pyproj/data/hawaii -> build/lib.macosx-10.13-x86_64-3.7/pyproj/data
#     copying lib/pyproj/data/nad27 -> build/lib.macosx-10.13-x86_64-3.7/pyproj/data
#     copying lib/pyproj/data/tv_out.dist -> build/lib.macosx-10.13-x86_64-3.7/pyproj/data
#     copying lib/pyproj/data/stgeorge -> build/lib.macosx-10.13-x86_64-3.7/pyproj/data
#     copying lib/pyproj/data/testdatumfile -> build/lib.macosx-10.13-x86_64-3.7/pyproj/data
#     copying lib/pyproj/data/stlrnc -> build/lib.macosx-10.13-x86_64-3.7/pyproj/data
#     copying lib/pyproj/data/GL27 -> build/lib.macosx-10.13-x86_64-3.7/pyproj/data
#     copying lib/pyproj/data/proj_outIGNF.dist -> build/lib.macosx-10.13-x86_64-3.7/pyproj/data
#     copying lib/pyproj/data/WI -> build/lib.macosx-10.13-x86_64-3.7/pyproj/data
#     copying lib/pyproj/data/TN -> build/lib.macosx-10.13-x86_64-3.7/pyproj/data
#     copying lib/pyproj/data/other.extra -> build/lib.macosx-10.13-x86_64-3.7/pyproj/data
#     copying lib/pyproj/data/WO -> build/lib.macosx-10.13-x86_64-3.7/pyproj/data
#     copying lib/pyproj/data/testIGNF -> build/lib.macosx-10.13-x86_64-3.7/pyproj/data
#     copying lib/pyproj/data/epsg -> build/lib.macosx-10.13-x86_64-3.7/pyproj/data
#     running build_ext
#     building 'pyproj._proj' extension
#     creating build/temp.macosx-10.13-x86_64-3.7
#     creating build/temp.macosx-10.13-x86_64-3.7/src
#     clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -Isrc -I/usr/local/include -I/usr/local/opt/openssl/include -I/usr/local/opt/sqlite/include -I/Users/chao/venv/include -I/usr/local/Cellar/python/3.7.0/Frameworks/Python.framework/Versions/3.7/include/python3.7m -c src/PJ_putp5.c -o build/temp.macosx-10.13-x86_64-3.7/src/PJ_putp5.o
#     clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -Isrc -I/usr/local/include -I/usr/local/opt/openssl/include -I/usr/local/opt/sqlite/include -I/Users/chao/venv/include -I/usr/local/Cellar/python/3.7.0/Frameworks/Python.framework/Versions/3.7/include/python3.7m -c src/proj_mdist.c -o build/temp.macosx-10.13-x86_64-3.7/src/proj_mdist.o
#     clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -Isrc -I/usr/local/include -I/usr/local/opt/openssl/include -I/usr/local/opt/sqlite/include -I/Users/chao/venv/include -I/usr/local/Cellar/python/3.7.0/Frameworks/Python.framework/Versions/3.7/include/python3.7m -c src/pj_datum_set.c -o build/temp.macosx-10.13-x86_64-3.7/src/pj_datum_set.o
#     clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -Isrc -I/usr/local/include -I/usr/local/opt/openssl/include -I/usr/local/opt/sqlite/include -I/Users/chao/venv/include -I/usr/local/Cellar/python/3.7.0/Frameworks/Python.framework/Versions/3.7/include/python3.7m -c src/pj_inv.c -o build/temp.macosx-10.13-x86_64-3.7/src/pj_inv.o
#     clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -Isrc -I/usr/local/include -I/usr/local/opt/openssl/include -I/usr/local/opt/sqlite/include -I/Users/chao/venv/include -I/usr/local/Cellar/python/3.7.0/Frameworks/Python.framework/Versions/3.7/include/python3.7m -c src/pj_apply_gridshift.c -o build/temp.macosx-10.13-x86_64-3.7/src/pj_apply_gridshift.o
#     clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -Isrc -I/usr/local/include -I/usr/local/opt/openssl/include -I/usr/local/opt/sqlite/include -I/Users/chao/venv/include -I/usr/local/Cellar/python/3.7.0/Frameworks/Python.framework/Versions/3.7/include/python3.7m -c src/emess.c -o build/temp.macosx-10.13-x86_64-3.7/src/emess.o
#     clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -Isrc -I/usr/local/include -I/usr/local/opt/openssl/include -I/usr/local/opt/sqlite/include -I/Users/chao/venv/include -I/usr/local/Cellar/python/3.7.0/Frameworks/Python.framework/Versions/3.7/include/python3.7m -c src/pj_param.c -o build/temp.macosx-10.13-x86_64-3.7/src/pj_param.o
#     clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -Isrc -I/usr/local/include -I/usr/local/opt/openssl/include -I/usr/local/opt/sqlite/include -I/Users/chao/venv/include -I/usr/local/Cellar/python/3.7.0/Frameworks/Python.framework/Versions/3.7/include/python3.7m -c src/PJ_nocol.c -o build/temp.macosx-10.13-x86_64-3.7/src/PJ_nocol.o
#     clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -Isrc -I/usr/local/include -I/usr/local/opt/openssl/include -I/usr/local/opt/sqlite/include -I/Users/chao/venv/include -I/usr/local/Cellar/python/3.7.0/Frameworks/Python.framework/Versions/3.7/include/python3.7m -c src/PJ_eck4.c -o build/temp.macosx-10.13-x86_64-3.7/src/PJ_eck4.o
#     clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -Isrc -I/usr/local/include -I/usr/local/opt/openssl/include -I/usr/local/opt/sqlite/include -I/Users/chao/venv/include -I/usr/local/Cellar/python/3.7.0/Frameworks/Python.framework/Versions/3.7/include/python3.7m -c src/PJ_gins8.c -o build/temp.macosx-10.13-x86_64-3.7/src/PJ_gins8.o
#     clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -Isrc -I/usr/local/include -I/usr/local/opt/openssl/include -I/usr/local/opt/sqlite/include -I/Users/chao/venv/include -I/usr/local/Cellar/python/3.7.0/Frameworks/Python.framework/Versions/3.7/include/python3.7m -c src/PJ_crast.c -o build/temp.macosx-10.13-x86_64-3.7/src/PJ_crast.o
#     clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -Isrc -I/usr/local/include -I/usr/local/opt/openssl/include -I/usr/local/opt/sqlite/include -I/Users/chao/venv/include -I/usr/local/Cellar/python/3.7.0/Frameworks/Python.framework/Versions/3.7/include/python3.7m -c src/pj_ellps.c -o build/temp.macosx-10.13-x86_64-3.7/src/pj_ellps.o
#     clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -Isrc -I/usr/local/include -I/usr/local/opt/openssl/include -I/usr/local/opt/sqlite/include -I/Users/chao/venv/include -I/usr/local/Cellar/python/3.7.0/Frameworks/Python.framework/Versions/3.7/include/python3.7m -c src/PJ_lagrng.c -o build/temp.macosx-10.13-x86_64-3.7/src/PJ_lagrng.o
#     clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -Isrc -I/usr/local/include -I/usr/local/opt/openssl/include -I/usr/local/opt/sqlite/include -I/Users/chao/venv/include -I/usr/local/Cellar/python/3.7.0/Frameworks/Python.framework/Versions/3.7/include/python3.7m -c src/PJ_denoy.c -o build/temp.macosx-10.13-x86_64-3.7/src/PJ_denoy.o
#     clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -Isrc -I/usr/local/include -I/usr/local/opt/openssl/include -I/usr/local/opt/sqlite/include -I/Users/chao/venv/include -I/usr/local/Cellar/python/3.7.0/Frameworks/Python.framework/Versions/3.7/include/python3.7m -c src/nad_cvt.c -o build/temp.macosx-10.13-x86_64-3.7/src/nad_cvt.o
#     clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -Isrc -I/usr/local/include -I/usr/local/opt/openssl/include -I/usr/local/opt/sqlite/include -I/Users/chao/venv/include -I/usr/local/Cellar/python/3.7.0/Frameworks/Python.framework/Versions/3.7/include/python3.7m -c src/PJ_laea.c -o build/temp.macosx-10.13-x86_64-3.7/src/PJ_laea.o
#     clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -Isrc -I/usr/local/include -I/usr/local/opt/openssl/include -I/usr/local/opt/sqlite/include -I/Users/chao/venv/include -I/usr/local/Cellar/python/3.7.0/Frameworks/Python.framework/Versions/3.7/include/python3.7m -c src/PJ_sterea.c -o build/temp.macosx-10.13-x86_64-3.7/src/PJ_sterea.o
#     clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -Isrc -I/usr/local/include -I/usr/local/opt/openssl/include -I/usr/local/opt/sqlite/include -I/Users/chao/venv/include -I/usr/local/Cellar/python/3.7.0/Frameworks/Python.framework/Versions/3.7/include/python3.7m -c src/PJ_mill.c -o build/temp.macosx-10.13-x86_64-3.7/src/PJ_mill.o
#     clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -Isrc -I/usr/local/include -I/usr/local/opt/openssl/include -I/usr/local/opt/sqlite/include -I/Users/chao/venv/include -I/usr/local/Cellar/python/3.7.0/Frameworks/Python.framework/Versions/3.7/include/python3.7m -c src/PJ_nell.c -o build/temp.macosx-10.13-x86_64-3.7/src/PJ_nell.o
#     clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -Isrc -I/usr/local/include -I/usr/local/opt/openssl/include -I/usr/local/opt/sqlite/include -I/Users/chao/venv/include -I/usr/local/Cellar/python/3.7.0/Frameworks/Python.framework/Versions/3.7/include/python3.7m -c src/pj_ctx.c -o build/temp.macosx-10.13-x86_64-3.7/src/pj_ctx.o
#     clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -Isrc -I/usr/local/include -I/usr/local/opt/openssl/include -I/usr/local/opt/sqlite/include -I/Users/chao/venv/include -I/usr/local/Cellar/python/3.7.0/Frameworks/Python.framework/Versions/3.7/include/python3.7m -c src/nad_init.c -o build/temp.macosx-10.13-x86_64-3.7/src/nad_init.o
#     clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -Isrc -I/usr/local/include -I/usr/local/opt/openssl/include -I/usr/local/opt/sqlite/include -I/Users/chao/venv/include -I/usr/local/Cellar/python/3.7.0/Frameworks/Python.framework/Versions/3.7/include/python3.7m -c src/PJ_tcc.c -o build/temp.macosx-10.13-x86_64-3.7/src/PJ_tcc.o
#     clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -Isrc -I/usr/local/include -I/usr/local/opt/openssl/include -I/usr/local/opt/sqlite/include -I/Users/chao/venv/include -I/usr/local/Cellar/python/3.7.0/Frameworks/Python.framework/Versions/3.7/include/python3.7m -c src/PJ_igh.c -o build/temp.macosx-10.13-x86_64-3.7/src/PJ_igh.o
#     clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -Isrc -I/usr/local/include -I/usr/local/opt/openssl/include -I/usr/local/opt/sqlite/include -I/Users/chao/venv/include -I/usr/local/Cellar/python/3.7.0/Frameworks/Python.framework/Versions/3.7/include/python3.7m -c src/PJ_chamb.c -o build/temp.macosx-10.13-x86_64-3.7/src/PJ_chamb.o
#     clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -Isrc -I/usr/local/include -I/usr/local/opt/openssl/include -I/usr/local/opt/sqlite/include -I/Users/chao/venv/include -I/usr/local/Cellar/python/3.7.0/Frameworks/Python.framework/Versions/3.7/include/python3.7m -c src/PJ_cc.c -o build/temp.macosx-10.13-x86_64-3.7/src/PJ_cc.o
#     clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -Isrc -I/usr/local/include -I/usr/local/opt/openssl/include -I/usr/local/opt/sqlite/include -I/Users/chao/venv/include -I/usr/local/Cellar/python/3.7.0/Frameworks/Python.framework/Versions/3.7/include/python3.7m -c src/pj_malloc.c -o build/temp.macosx-10.13-x86_64-3.7/src/pj_malloc.o
#     clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -Isrc -I/usr/local/include -I/usr/local/opt/openssl/include -I/usr/local/opt/sqlite/include -I/Users/chao/venv/include -I/usr/local/Cellar/python/3.7.0/Frameworks/Python.framework/Versions/3.7/include/python3.7m -c src/pj_msfn.c -o build/temp.macosx-10.13-x86_64-3.7/src/pj_msfn.o
#     clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -Isrc -I/usr/local/include -I/usr/local/opt/openssl/include -I/usr/local/opt/sqlite/include -I/Users/chao/venv/include -I/usr/local/Cellar/python/3.7.0/Frameworks/Python.framework/Versions/3.7/include/python3.7m -c src/PJ_boggs.c -o build/temp.macosx-10.13-x86_64-3.7/src/PJ_boggs.o
#     clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -Isrc -I/usr/local/include -I/usr/local/opt/openssl/include -I/usr/local/opt/sqlite/include -I/Users/chao/venv/include -I/usr/local/Cellar/python/3.7.0/Frameworks/Python.framework/Versions/3.7/include/python3.7m -c src/PJ_nzmg.c -o build/temp.macosx-10.13-x86_64-3.7/src/PJ_nzmg.o
#     clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -Isrc -I/usr/local/include -I/usr/local/opt/openssl/include -I/usr/local/opt/sqlite/include -I/Users/chao/venv/include -I/usr/local/Cellar/python/3.7.0/Frameworks/Python.framework/Versions/3.7/include/python3.7m -c src/pj_gauss.c -o build/temp.macosx-10.13-x86_64-3.7/src/pj_gauss.o
#     clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -Isrc -I/usr/local/include -I/usr/local/opt/openssl/include -I/usr/local/opt/sqlite/include -I/Users/chao/venv/include -I/usr/local/Cellar/python/3.7.0/Frameworks/Python.framework/Versions/3.7/include/python3.7m -c src/PJ_tcea.c -o build/temp.macosx-10.13-x86_64-3.7/src/PJ_tcea.o
#     clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -Isrc -I/usr/local/include -I/usr/local/opt/openssl/include -I/usr/local/opt/sqlite/include -I/Users/chao/venv/include -I/usr/local/Cellar/python/3.7.0/Frameworks/Python.framework/Versions/3.7/include/python3.7m -c src/PJ_eqdc.c -o build/temp.macosx-10.13-x86_64-3.7/src/PJ_eqdc.o
#     clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -Isrc -I/usr/local/include -I/usr/local/opt/openssl/include -I/usr/local/opt/sqlite/include -I/Users/chao/venv/include -I/usr/local/Cellar/python/3.7.0/Frameworks/Python.framework/Versions/3.7/include/python3.7m -c src/PJ_bipc.c -o build/temp.macosx-10.13-x86_64-3.7/src/PJ_bipc.o
#     clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -Isrc -I/usr/local/include -I/usr/local/opt/openssl/include -I/usr/local/opt/sqlite/include -I/Users/chao/venv/include -I/usr/local/Cellar/python/3.7.0/Frameworks/Python.framework/Versions/3.7/include/python3.7m -c src/PJ_moll.c -o build/temp.macosx-10.13-x86_64-3.7/src/PJ_moll.o
#     clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -Isrc -I/usr/local/include -I/usr/local/opt/openssl/include -I/usr/local/opt/sqlite/include -I/Users/chao/venv/include -I/usr/local/Cellar/python/3.7.0/Frameworks/Python.framework/Versions/3.7/include/python3.7m -c src/pj_fwd3d.c -o build/temp.macosx-10.13-x86_64-3.7/src/pj_fwd3d.o
#     clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -Isrc -I/usr/local/include -I/usr/local/opt/openssl/include -I/usr/local/opt/sqlite/include -I/Users/chao/venv/include -I/usr/local/Cellar/python/3.7.0/Frameworks/Python.framework/Versions/3.7/include/python3.7m -c src/PJ_robin.c -o build/temp.macosx-10.13-x86_64-3.7/src/PJ_robin.o
#     clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -Isrc -I/usr/local/include -I/usr/local/opt/openssl/include -I/usr/local/opt/sqlite/include -I/Users/chao/venv/include -I/usr/local/Cellar/python/3.7.0/Frameworks/Python.framework/Versions/3.7/include/python3.7m -c src/PJ_imw_p.c -o build/temp.macosx-10.13-x86_64-3.7/src/PJ_imw_p.o
#     clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -Isrc -I/usr/local/include -I/usr/local/opt/openssl/include -I/usr/local/opt/sqlite/include -I/Users/chao/venv/include -I/usr/local/Cellar/python/3.7.0/Frameworks/Python.framework/Versions/3.7/include/python3.7m -c src/geod_interface.c -o build/temp.macosx-10.13-x86_64-3.7/src/geod_interface.o
#     clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -Isrc -I/usr/local/include -I/usr/local/opt/openssl/include -I/usr/local/opt/sqlite/include -I/Users/chao/venv/include -I/usr/local/Cellar/python/3.7.0/Frameworks/Python.framework/Versions/3.7/include/python3.7m -c src/PJ_mod_ster.c -o build/temp.macosx-10.13-x86_64-3.7/src/PJ_mod_ster.o
#     clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -Isrc -I/usr/local/include -I/usr/local/opt/openssl/include -I/usr/local/opt/sqlite/include -I/Users/chao/venv/include -I/usr/local/Cellar/python/3.7.0/Frameworks/Python.framework/Versions/3.7/include/python3.7m -c src/PJ_geos.c -o build/temp.macosx-10.13-x86_64-3.7/src/PJ_geos.o
#     clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -Isrc -I/usr/local/include -I/usr/local/opt/openssl/include -I/usr/local/opt/sqlite/include -I/Users/chao/venv/include -I/usr/local/Cellar/python/3.7.0/Frameworks/Python.framework/Versions/3.7/include/python3.7m -c src/pj_tsfn.c -o build/temp.macosx-10.13-x86_64-3.7/src/pj_tsfn.o
#     clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -Isrc -I/usr/local/include -I/usr/local/opt/openssl/include -I/usr/local/opt/sqlite/include -I/Users/chao/venv/include -I/usr/local/Cellar/python/3.7.0/Frameworks/Python.framework/Versions/3.7/include/python3.7m -c src/PJ_vandg4.c -o build/temp.macosx-10.13-x86_64-3.7/src/PJ_vandg4.o
#     clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -Isrc -I/usr/local/include -I/usr/local/opt/openssl/include -I/usr/local/opt/sqlite/include -I/Users/chao/venv/include -I/usr/local/Cellar/python/3.7.0/Frameworks/Python.framework/Versions/3.7/include/python3.7m -c src/PJ_tmerc.c -o build/temp.macosx-10.13-x86_64-3.7/src/PJ_tmerc.o
#     clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -Isrc -I/usr/local/include -I/usr/local/opt/openssl/include -I/usr/local/opt/sqlite/include -I/Users/chao/venv/include -I/usr/local/Cellar/python/3.7.0/Frameworks/Python.framework/Versions/3.7/include/python3.7m -c src/PJ_omerc.c -o build/temp.macosx-10.13-x86_64-3.7/src/PJ_omerc.o
#     clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -Isrc -I/usr/local/include -I/usr/local/opt/openssl/include -I/usr/local/opt/sqlite/include -I/Users/chao/venv/include -I/usr/local/Cellar/python/3.7.0/Frameworks/Python.framework/Versions/3.7/include/python3.7m -c src/PJ_putp6.c -o build/temp.macosx-10.13-x86_64-3.7/src/PJ_putp6.o
#     clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -Isrc -I/usr/local/include -I/usr/local/opt/openssl/include -I/usr/local/opt/sqlite/include -I/Users/chao/venv/include -I/usr/local/Cellar/python/3.7.0/Frameworks/Python.framework/Versions/3.7/include/python3.7m -c src/PJ_aea.c -o build/temp.macosx-10.13-x86_64-3.7/src/PJ_aea.o
#     clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -Isrc -I/usr/local/include -I/usr/local/opt/openssl/include -I/usr/local/opt/sqlite/include -I/Users/chao/venv/include -I/usr/local/Cellar/python/3.7.0/Frameworks/Python.framework/Versions/3.7/include/python3.7m -c src/PJ_lsat.c -o build/temp.macosx-10.13-x86_64-3.7/src/PJ_lsat.o
#     clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -Isrc -I/usr/local/include -I/usr/local/opt/openssl/include -I/usr/local/opt/sqlite/include -I/Users/chao/venv/include -I/usr/local/Cellar/python/3.7.0/Frameworks/Python.framework/Versions/3.7/include/python3.7m -c src/PJ_lask.c -o build/temp.macosx-10.13-x86_64-3.7/src/PJ_lask.o
#     clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -Isrc -I/usr/local/include -I/usr/local/opt/openssl/include -I/usr/local/opt/sqlite/include -I/Users/chao/venv/include -I/usr/local/Cellar/python/3.7.0/Frameworks/Python.framework/Versions/3.7/include/python3.7m -c src/pj_datums.c -o build/temp.macosx-10.13-x86_64-3.7/src/pj_datums.o
#     clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -Isrc -I/usr/local/include -I/usr/local/opt/openssl/include -I/usr/local/opt/sqlite/include -I/Users/chao/venv/include -I/usr/local/Cellar/python/3.7.0/Frameworks/Python.framework/Versions/3.7/include/python3.7m -c src/PJ_goode.c -o build/temp.macosx-10.13-x86_64-3.7/src/PJ_goode.o
#     clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -Isrc -I/usr/local/include -I/usr/local/opt/openssl/include -I/usr/local/opt/sqlite/include -I/Users/chao/venv/include -I/usr/local/Cellar/python/3.7.0/Frameworks/Python.framework/Versions/3.7/include/python3.7m -c src/PJ_aeqd.c -o build/temp.macosx-10.13-x86_64-3.7/src/PJ_aeqd.o
#     clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -Isrc -I/usr/local/include -I/usr/local/opt/openssl/include -I/usr/local/opt/sqlite/include -I/Users/chao/venv/include -I/usr/local/Cellar/python/3.7.0/Frameworks/Python.framework/Versions/3.7/include/python3.7m -c src/pj_mutex.c -o build/temp.macosx-10.13-x86_64-3.7/src/pj_mutex.o
#     clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -Isrc -I/usr/local/include -I/usr/local/opt/openssl/include -I/usr/local/opt/sqlite/include -I/Users/chao/venv/include -I/usr/local/Cellar/python/3.7.0/Frameworks/Python.framework/Versions/3.7/include/python3.7m -c src/PJ_cea.c -o build/temp.macosx-10.13-x86_64-3.7/src/PJ_cea.o
#     clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -Isrc -I/usr/local/include -I/usr/local/opt/openssl/include -I/usr/local/opt/sqlite/include -I/Users/chao/venv/include -I/usr/local/Cellar/python/3.7.0/Frameworks/Python.framework/Versions/3.7/include/python3.7m -c src/PJ_putp2.c -o build/temp.macosx-10.13-x86_64-3.7/src/PJ_putp2.o
#     clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -Isrc -I/usr/local/include -I/usr/local/opt/openssl/include -I/usr/local/opt/sqlite/include -I/Users/chao/venv/include -I/usr/local/Cellar/python/3.7.0/Frameworks/Python.framework/Versions/3.7/include/python3.7m -c src/PJ_gn_sinu.c -o build/temp.macosx-10.13-x86_64-3.7/src/PJ_gn_sinu.o
#     clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -Isrc -I/usr/local/include -I/usr/local/opt/openssl/include -I/usr/local/opt/sqlite/include -I/Users/chao/venv/include -I/usr/local/Cellar/python/3.7.0/Frameworks/Python.framework/Versions/3.7/include/python3.7m -c src/PJ_krovak.c -o build/temp.macosx-10.13-x86_64-3.7/src/PJ_krovak.o
#     clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -Isrc -I/usr/local/include -I/usr/local/opt/openssl/include -I/usr/local/opt/sqlite/include -I/Users/chao/venv/include -I/usr/local/Cellar/python/3.7.0/Frameworks/Python.framework/Versions/3.7/include/python3.7m -c src/PJ_rpoly.c -o build/temp.macosx-10.13-x86_64-3.7/src/PJ_rpoly.o
#     clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -Isrc -I/usr/local/include -I/usr/local/opt/openssl/include -I/usr/local/opt/sqlite/include -I/Users/chao/venv/include -I/usr/local/Cellar/python/3.7.0/Frameworks/Python.framework/Versions/3.7/include/python3.7m -c src/pj_latlong.c -o build/temp.macosx-10.13-x86_64-3.7/src/pj_latlong.o
#     clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -Isrc -I/usr/local/include -I/usr/local/opt/openssl/include -I/usr/local/opt/sqlite/include -I/Users/chao/venv/include -I/usr/local/Cellar/python/3.7.0/Frameworks/Python.framework/Versions/3.7/include/python3.7m -c src/PJ_healpix.c -o build/temp.macosx-10.13-x86_64-3.7/src/PJ_healpix.o
#     clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -Isrc -I/usr/local/include -I/usr/local/opt/openssl/include -I/usr/local/opt/sqlite/include -I/Users/chao/venv/include -I/usr/local/Cellar/python/3.7.0/Frameworks/Python.framework/Versions/3.7/include/python3.7m -c src/biveval.c -o build/temp.macosx-10.13-x86_64-3.7/src/biveval.o
#     clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -Isrc -I/usr/local/include -I/usr/local/opt/openssl/include -I/usr/local/opt/sqlite/include -I/Users/chao/venv/include -I/usr/local/Cellar/python/3.7.0/Frameworks/Python.framework/Versions/3.7/include/python3.7m -c src/pj_errno.c -o build/temp.macosx-10.13-x86_64-3.7/src/pj_errno.o
#     clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -Isrc -I/usr/local/include -I/usr/local/opt/openssl/include -I/usr/local/opt/sqlite/include -I/Users/chao/venv/include -I/usr/local/Cellar/python/3.7.0/Frameworks/Python.framework/Versions/3.7/include/python3.7m -c src/PJ_eck3.c -o build/temp.macosx-10.13-x86_64-3.7/src/PJ_eck3.o
#     clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -Isrc -I/usr/local/include -I/usr/local/opt/openssl/include -I/usr/local/opt/sqlite/include -I/Users/chao/venv/include -I/usr/local/Cellar/python/3.7.0/Frameworks/Python.framework/Versions/3.7/include/python3.7m -c src/PJ_gnom.c -o build/temp.macosx-10.13-x86_64-3.7/src/PJ_gnom.o
#     clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -Isrc -I/usr/local/include -I/usr/local/opt/openssl/include -I/usr/local/opt/sqlite/include -I/Users/chao/venv/include -I/usr/local/Cellar/python/3.7.0/Frameworks/Python.framework/Versions/3.7/include/python3.7m -c src/bchgen.c -o build/temp.macosx-10.13-x86_64-3.7/src/bchgen.o
#     clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -Isrc -I/usr/local/include -I/usr/local/opt/openssl/include -I/usr/local/opt/sqlite/include -I/Users/chao/venv/include -I/usr/local/Cellar/python/3.7.0/Frameworks/Python.framework/Versions/3.7/include/python3.7m -c src/pj_strerrno.c -o build/temp.macosx-10.13-x86_64-3.7/src/pj_strerrno.o
#     clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -Isrc -I/usr/local/include -I/usr/local/opt/openssl/include -I/usr/local/opt/sqlite/include -I/Users/chao/venv/include -I/usr/local/Cellar/python/3.7.0/Frameworks/Python.framework/Versions/3.7/include/python3.7m -c src/PJ_natearth.c -o build/temp.macosx-10.13-x86_64-3.7/src/PJ_natearth.o
#     clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -Isrc -I/usr/local/include -I/usr/local/opt/openssl/include -I/usr/local/opt/sqlite/include -I/Users/chao/venv/include -I/usr/local/Cellar/python/3.7.0/Frameworks/Python.framework/Versions/3.7/include/python3.7m -c src/pj_log.c -o build/temp.macosx-10.13-x86_64-3.7/src/pj_log.o
#     clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -Isrc -I/usr/local/include -I/usr/local/opt/openssl/include -I/usr/local/opt/sqlite/include -I/Users/chao/venv/include -I/usr/local/Cellar/python/3.7.0/Frameworks/Python.framework/Versions/3.7/include/python3.7m -c src/pj_factors.c -o build/temp.macosx-10.13-x86_64-3.7/src/pj_factors.o
#     clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -Isrc -I/usr/local/include -I/usr/local/opt/openssl/include -I/usr/local/opt/sqlite/include -I/Users/chao/venv/include -I/usr/local/Cellar/python/3.7.0/Frameworks/Python.framework/Versions/3.7/include/python3.7m -c src/PJ_wag2.c -o build/temp.macosx-10.13-x86_64-3.7/src/PJ_wag2.o
#     clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -Isrc -I/usr/local/include -I/usr/local/opt/openssl/include -I/usr/local/opt/sqlite/include -I/Users/chao/venv/include -I/usr/local/Cellar/python/3.7.0/Frameworks/Python.framework/Versions/3.7/include/python3.7m -c src/PJ_collg.c -o build/temp.macosx-10.13-x86_64-3.7/src/PJ_collg.o
#     clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -Isrc -I/usr/local/include -I/usr/local/opt/openssl/include -I/usr/local/opt/sqlite/include -I/Users/chao/venv/include -I/usr/local/Cellar/python/3.7.0/Frameworks/Python.framework/Versions/3.7/include/python3.7m -c src/PJ_labrd.c -o build/temp.macosx-10.13-x86_64-3.7/src/PJ_labrd.o
#     clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -Isrc -I/usr/local/include -I/usr/local/opt/openssl/include -I/usr/local/opt/sqlite/include -I/Users/chao/venv/include -I/usr/local/Cellar/python/3.7.0/Frameworks/Python.framework/Versions/3.7/include/python3.7m -c src/PJ_ortho.c -o build/temp.macosx-10.13-x86_64-3.7/src/PJ_ortho.o
#     clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -Isrc -I/usr/local/include -I/usr/local/opt/openssl/include -I/usr/local/opt/sqlite/include -I/Users/chao/venv/include -I/usr/local/Cellar/python/3.7.0/Frameworks/Python.framework/Versions/3.7/include/python3.7m -c src/PJ_urmfps.c -o build/temp.macosx-10.13-x86_64-3.7/src/PJ_urmfps.o
#     clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -Isrc -I/usr/local/include -I/usr/local/opt/openssl/include -I/usr/local/opt/sqlite/include -I/Users/chao/venv/include -I/usr/local/Cellar/python/3.7.0/Frameworks/Python.framework/Versions/3.7/include/python3.7m -c src/pj_ell_set.c -o build/temp.macosx-10.13-x86_64-3.7/src/pj_ell_set.o
#     clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -Isrc -I/usr/local/include -I/usr/local/opt/openssl/include -I/usr/local/opt/sqlite/include -I/Users/chao/venv/include -I/usr/local/Cellar/python/3.7.0/Frameworks/Python.framework/Versions/3.7/include/python3.7m -c src/pj_strtod.c -o build/temp.macosx-10.13-x86_64-3.7/src/pj_strtod.o
#     src/pj_strtod.c:83:2: warning: "localeconv not available" [-W#warnings]
#     #warning "localeconv not available"
#      ^
#     1 warning generated.
#     clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -Isrc -I/usr/local/include -I/usr/local/opt/openssl/include -I/usr/local/opt/sqlite/include -I/Users/chao/venv/include -I/usr/local/Cellar/python/3.7.0/Frameworks/Python.framework/Versions/3.7/include/python3.7m -c src/p_series.c -o build/temp.macosx-10.13-x86_64-3.7/src/p_series.o
#     clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -Isrc -I/usr/local/include -I/usr/local/opt/openssl/include -I/usr/local/opt/sqlite/include -I/Users/chao/venv/include -I/usr/local/Cellar/python/3.7.0/Frameworks/Python.framework/Versions/3.7/include/python3.7m -c src/PJ_eqc.c -o build/temp.macosx-10.13-x86_64-3.7/src/PJ_eqc.o
#     clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -Isrc -I/usr/local/include -I/usr/local/opt/openssl/include -I/usr/local/opt/sqlite/include -I/Users/chao/venv/include -I/usr/local/Cellar/python/3.7.0/Frameworks/Python.framework/Versions/3.7/include/python3.7m -c src/PJ_nsper.c -o build/temp.macosx-10.13-x86_64-3.7/src/PJ_nsper.o
#     clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -Isrc -I/usr/local/include -I/usr/local/opt/openssl/include -I/usr/local/opt/sqlite/include -I/Users/chao/venv/include -I/usr/local/Cellar/python/3.7.0/Frameworks/Python.framework/Versions/3.7/include/python3.7m -c src/pj_units.c -o build/temp.macosx-10.13-x86_64-3.7/src/pj_units.o
#     clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -Isrc -I/usr/local/include -I/usr/local/opt/openssl/include -I/usr/local/opt/sqlite/include -I/Users/chao/venv/include -I/usr/local/Cellar/python/3.7.0/Frameworks/Python.framework/Versions/3.7/include/python3.7m -c src/PJ_mbtfpq.c -o build/temp.macosx-10.13-x86_64-3.7/src/PJ_mbtfpq.o
#     clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -Isrc -I/usr/local/include -I/usr/local/opt/openssl/include -I/usr/local/opt/sqlite/include -I/Users/chao/venv/include -I/usr/local/Cellar/python/3.7.0/Frameworks/Python.framework/Versions/3.7/include/python3.7m -c src/PJ_bonne.c -o build/temp.macosx-10.13-x86_64-3.7/src/PJ_bonne.o
#     clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -Isrc -I/usr/local/include -I/usr/local/opt/openssl/include -I/usr/local/opt/sqlite/include -I/Users/chao/venv/include -I/usr/local/Cellar/python/3.7.0/Frameworks/Python.framework/Versions/3.7/include/python3.7m -c src/PJ_tpeqd.c -o build/temp.macosx-10.13-x86_64-3.7/src/PJ_tpeqd.o
#     clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -Isrc -I/usr/local/include -I/usr/local/opt/openssl/include -I/usr/local/opt/sqlite/include -I/Users/chao/venv/include -I/usr/local/Cellar/python/3.7.0/Frameworks/Python.framework/Versions/3.7/include/python3.7m -c src/pj_zpoly1.c -o build/temp.macosx-10.13-x86_64-3.7/src/pj_zpoly1.o
#     clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -Isrc -I/usr/local/include -I/usr/local/opt/openssl/include -I/usr/local/opt/sqlite/include -I/Users/chao/venv/include -I/usr/local/Cellar/python/3.7.0/Frameworks/Python.framework/Versions/3.7/include/python3.7m -c src/dmstor.c -o build/temp.macosx-10.13-x86_64-3.7/src/dmstor.o
#     clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -Isrc -I/usr/local/include -I/usr/local/opt/openssl/include -I/usr/local/opt/sqlite/include -I/Users/chao/venv/include -I/usr/local/Cellar/python/3.7.0/Frameworks/Python.framework/Versions/3.7/include/python3.7m -c src/PJ_somerc.c -o build/temp.macosx-10.13-x86_64-3.7/src/PJ_somerc.o
#     clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -Isrc -I/usr/local/include -I/usr/local/opt/openssl/include -I/usr/local/opt/sqlite/include -I/Users/chao/venv/include -I/usr/local/Cellar/python/3.7.0/Frameworks/Python.framework/Versions/3.7/include/python3.7m -c src/PJ_cass.c -o build/temp.macosx-10.13-x86_64-3.7/src/PJ_cass.o
#     clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -Isrc -I/usr/local/include -I/usr/local/opt/openssl/include -I/usr/local/opt/sqlite/include -I/Users/chao/venv/include -I/usr/local/Cellar/python/3.7.0/Frameworks/Python.framework/Versions/3.7/include/python3.7m -c src/PJ_urm5.c -o build/temp.macosx-10.13-x86_64-3.7/src/PJ_urm5.o
#     clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -Isrc -I/usr/local/include -I/usr/local/opt/openssl/include -I/usr/local/opt/sqlite/include -I/Users/chao/venv/include -I/usr/local/Cellar/python/3.7.0/Frameworks/Python.framework/Versions/3.7/include/python3.7m -c src/PJ_isea.c -o build/temp.macosx-10.13-x86_64-3.7/src/PJ_isea.o
#     src/PJ_isea.c:921:6: warning: code will never be executed [-Wunreachable-code]
#             d = v.x;
#                 ^
#     1 warning generated.
#     clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -Isrc -I/usr/local/include -I/usr/local/opt/openssl/include -I/usr/local/opt/sqlite/include -I/Users/chao/venv/include -I/usr/local/Cellar/python/3.7.0/Frameworks/Python.framework/Versions/3.7/include/python3.7m -c src/PJ_wink2.c -o build/temp.macosx-10.13-x86_64-3.7/src/PJ_wink2.o
#     clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -Isrc -I/usr/local/include -I/usr/local/opt/openssl/include -I/usr/local/opt/sqlite/include -I/Users/chao/venv/include -I/usr/local/Cellar/python/3.7.0/Frameworks/Python.framework/Versions/3.7/include/python3.7m -c src/pj_gridinfo.c -o build/temp.macosx-10.13-x86_64-3.7/src/pj_gridinfo.o
#     clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -Isrc -I/usr/local/include -I/usr/local/opt/openssl/include -I/usr/local/opt/sqlite/include -I/Users/chao/venv/include -I/usr/local/Cellar/python/3.7.0/Frameworks/Python.framework/Versions/3.7/include/python3.7m -c src/pj_utils.c -o build/temp.macosx-10.13-x86_64-3.7/src/pj_utils.o
#     clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -Isrc -I/usr/local/include -I/usr/local/opt/openssl/include -I/usr/local/opt/sqlite/include -I/Users/chao/venv/include -I/usr/local/Cellar/python/3.7.0/Frameworks/Python.framework/Versions/3.7/include/python3.7m -c src/PJ_putp3.c -o build/temp.macosx-10.13-x86_64-3.7/src/PJ_putp3.o
#     clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -Isrc -I/usr/local/include -I/usr/local/opt/openssl/include -I/usr/local/opt/sqlite/include -I/Users/chao/venv/include -I/usr/local/Cellar/python/3.7.0/Frameworks/Python.framework/Versions/3.7/include/python3.7m -c src/PJ_gstmerc.c -o build/temp.macosx-10.13-x86_64-3.7/src/PJ_gstmerc.o
#     clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -Isrc -I/usr/local/include -I/usr/local/opt/openssl/include -I/usr/local/opt/sqlite/include -I/Users/chao/venv/include -I/usr/local/Cellar/python/3.7.0/Frameworks/Python.framework/Versions/3.7/include/python3.7m -c src/PJ_larr.c -o build/temp.macosx-10.13-x86_64-3.7/src/PJ_larr.o
#     clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -Isrc -I/usr/local/include -I/usr/local/opt/openssl/include -I/usr/local/opt/sqlite/include -I/Users/chao/venv/include -I/usr/local/Cellar/python/3.7.0/Frameworks/Python.framework/Versions/3.7/include/python3.7m -c src/PJ_hatano.c -o build/temp.macosx-10.13-x86_64-3.7/src/PJ_hatano.o
#     clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -Isrc -I/usr/local/include -I/usr/local/opt/openssl/include -I/usr/local/opt/sqlite/include -I/Users/chao/venv/include -I/usr/local/Cellar/python/3.7.0/Frameworks/Python.framework/Versions/3.7/include/python3.7m -c src/PJ_aitoff.c -o build/temp.macosx-10.13-x86_64-3.7/src/PJ_aitoff.o
#     clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -Isrc -I/usr/local/include -I/usr/local/opt/openssl/include -I/usr/local/opt/sqlite/include -I/Users/chao/venv/include -I/usr/local/Cellar/python/3.7.0/Frameworks/Python.framework/Versions/3.7/include/python3.7m -c src/pj_geocent.c -o build/temp.macosx-10.13-x86_64-3.7/src/pj_geocent.o
#     clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -Isrc -I/usr/local/include -I/usr/local/opt/openssl/include -I/usr/local/opt/sqlite/include -I/Users/chao/venv/include -I/usr/local/Cellar/python/3.7.0/Frameworks/Python.framework/Versions/3.7/include/python3.7m -c src/PJ_gall.c -o build/temp.macosx-10.13-x86_64-3.7/src/PJ_gall.o
#     clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -Isrc -I/usr/local/include -I/usr/local/opt/openssl/include -I/usr/local/opt/sqlite/include -I/Users/chao/venv/include -I/usr/local/Cellar/python/3.7.0/Frameworks/Python.framework/Versions/3.7/include/python3.7m -c src/PJ_eck2.c -o build/temp.macosx-10.13-x86_64-3.7/src/PJ_eck2.o
#     clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -Isrc -I/usr/local/include -I/usr/local/opt/openssl/include -I/usr/local/opt/sqlite/include -I/Users/chao/venv/include -I/usr/local/Cellar/python/3.7.0/Frameworks/Python.framework/Versions/3.7/include/python3.7m -c src/pj_phi2.c -o build/temp.macosx-10.13-x86_64-3.7/src/pj_phi2.o
#     clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -Isrc -I/usr/local/include -I/usr/local/opt/openssl/include -I/usr/local/opt/sqlite/include -I/Users/chao/venv/include -I/usr/local/Cellar/python/3.7.0/Frameworks/Python.framework/Versions/3.7/include/python3.7m -c src/geodesic.c -o build/temp.macosx-10.13-x86_64-3.7/src/geodesic.o
# ...
#                     ^
#     /usr/local/Cellar/python/3.7.0/Frameworks/Python.framework/Versions/3.7/include/python3.7m/abstract.h:503:40: note: 'PyObject_AsWriteBuffer' has been explicitly marked deprecated here
#                                            Py_DEPRECATED(3.0);
#                                            ^
#     /usr/local/Cellar/python/3.7.0/Frameworks/Python.framework/Versions/3.7/include/python3.7m/pyport.h:493:54: note: expanded from macro 'Py_DEPRECATED'
#     #define Py_DEPRECATED(VERSION_UNUSED) __attribute__((__deprecated__))
#                                                          ^
#     _proj.c:2325:17: warning: 'PyObject_AsWriteBuffer' is deprecated [-Wdeprecated-declarations]
#       __pyx_t_1 = ((PyObject_AsWriteBuffer(__pyx_v_y, (&__pyx_v_ydata), (&__pyx_v_bufleny)) != 0) != 0);
#                     ^
#     /usr/local/Cellar/python/3.7.0/Frameworks/Python.framework/Versions/3.7/include/python3.7m/abstract.h:503:40: note: 'PyObject_AsWriteBuffer' has been explicitly marked deprecated here
#                                            Py_DEPRECATED(3.0);
#                                            ^
#     /usr/local/Cellar/python/3.7.0/Frameworks/Python.framework/Versions/3.7/include/python3.7m/pyport.h:493:54: note: expanded from macro 'Py_DEPRECATED'
#     #define Py_DEPRECATED(VERSION_UNUSED) __attribute__((__deprecated__))
#                                                          ^
#     _proj.c:3408:17: warning: 'PyObject_AsWriteBuffer' is deprecated [-Wdeprecated-declarations]
#       __pyx_t_1 = ((PyObject_AsWriteBuffer(__pyx_v_inx, (&__pyx_v_xdata), (&__pyx_v_buflenx)) != 0) != 0);
#                     ^
#     /usr/local/Cellar/python/3.7.0/Frameworks/Python.framework/Versions/3.7/include/python3.7m/abstract.h:503:40: note: 'PyObject_AsWriteBuffer' has been explicitly marked deprecated here
#                                            Py_DEPRECATED(3.0);
#                                            ^
#     /usr/local/Cellar/python/3.7.0/Frameworks/Python.framework/Versions/3.7/include/python3.7m/pyport.h:493:54: note: expanded from macro 'Py_DEPRECATED'
#     #define Py_DEPRECATED(VERSION_UNUSED) __attribute__((__deprecated__))
#                                                          ^
#     _proj.c:3437:17: warning: 'PyObject_AsWriteBuffer' is deprecated [-Wdeprecated-declarations]
#       __pyx_t_1 = ((PyObject_AsWriteBuffer(__pyx_v_iny, (&__pyx_v_ydata), (&__pyx_v_bufleny)) != 0) != 0);
#                     ^
#     /usr/local/Cellar/python/3.7.0/Frameworks/Python.framework/Versions/3.7/include/python3.7m/abstract.h:503:40: note: 'PyObject_AsWriteBuffer' has been explicitly marked deprecated here
#                                            Py_DEPRECATED(3.0);
#                                            ^
#     /usr/local/Cellar/python/3.7.0/Frameworks/Python.framework/Versions/3.7/include/python3.7m/pyport.h:493:54: note: expanded from macro 'Py_DEPRECATED'
#     #define Py_DEPRECATED(VERSION_UNUSED) __attribute__((__deprecated__))
#                                                          ^
#     _proj.c:3477:19: warning: 'PyObject_AsWriteBuffer' is deprecated [-Wdeprecated-declarations]
#         __pyx_t_2 = ((PyObject_AsWriteBuffer(__pyx_v_inz, (&__pyx_v_zdata), (&__pyx_v_buflenz)) != 0) != 0);
#                       ^
#     /usr/local/Cellar/python/3.7.0/Frameworks/Python.framework/Versions/3.7/include/python3.7m/abstract.h:503:40: note: 'PyObject_AsWriteBuffer' has been explicitly marked deprecated here
#                                            Py_DEPRECATED(3.0);
#                                            ^
#     /usr/local/Cellar/python/3.7.0/Frameworks/Python.framework/Versions/3.7/include/python3.7m/pyport.h:493:54: note: expanded from macro 'Py_DEPRECATED'
#     #define Py_DEPRECATED(VERSION_UNUSED) __attribute__((__deprecated__))
#                                                          ^
#     _proj.c:4412:17: warning: 'PyObject_AsWriteBuffer' is deprecated [-Wdeprecated-declarations]
#       __pyx_t_1 = ((PyObject_AsWriteBuffer(__pyx_v_lons, (&__pyx_v_londata), (&__pyx_v_buflenlons)) != 0) != 0);
#                     ^
#     /usr/local/Cellar/python/3.7.0/Frameworks/Python.framework/Versions/3.7/include/python3.7m/abstract.h:503:40: note: 'PyObject_AsWriteBuffer' has been explicitly marked deprecated here
#                                            Py_DEPRECATED(3.0);
#                                            ^
#     /usr/local/Cellar/python/3.7.0/Frameworks/Python.framework/Versions/3.7/include/python3.7m/pyport.h:493:54: note: expanded from macro 'Py_DEPRECATED'
#     #define Py_DEPRECATED(VERSION_UNUSED) __attribute__((__deprecated__))
#                                                          ^
#     _proj.c:4441:17: warning: 'PyObject_AsWriteBuffer' is deprecated [-Wdeprecated-declarations]
#       __pyx_t_1 = ((PyObject_AsWriteBuffer(__pyx_v_lats, (&__pyx_v_latdata), (&__pyx_v_buflenlats)) != 0) != 0);
#                     ^
#     /usr/local/Cellar/python/3.7.0/Frameworks/Python.framework/Versions/3.7/include/python3.7m/abstract.h:503:40: note: 'PyObject_AsWriteBuffer' has been explicitly marked deprecated here
#                                            Py_DEPRECATED(3.0);
#                                            ^
#     /usr/local/Cellar/python/3.7.0/Frameworks/Python.framework/Versions/3.7/include/python3.7m/pyport.h:493:54: note: expanded from macro 'Py_DEPRECATED'
#     #define Py_DEPRECATED(VERSION_UNUSED) __attribute__((__deprecated__))
#                                                          ^
#     _proj.c:4470:17: warning: 'PyObject_AsWriteBuffer' is deprecated [-Wdeprecated-declarations]
#       __pyx_t_1 = ((PyObject_AsWriteBuffer(__pyx_v_az, (&__pyx_v_azdat), (&__pyx_v_buflenaz)) != 0) != 0);
#                     ^
#     /usr/local/Cellar/python/3.7.0/Frameworks/Python.framework/Versions/3.7/include/python3.7m/abstract.h:503:40: note: 'PyObject_AsWriteBuffer' has been explicitly marked deprecated here
#                                            Py_DEPRECATED(3.0);
#                                            ^
#     /usr/local/Cellar/python/3.7.0/Frameworks/Python.framework/Versions/3.7/include/python3.7m/pyport.h:493:54: note: expanded from macro 'Py_DEPRECATED'
#     #define Py_DEPRECATED(VERSION_UNUSED) __attribute__((__deprecated__))
#                                                          ^
#     _proj.c:4499:17: warning: 'PyObject_AsWriteBuffer' is deprecated [-Wdeprecated-declarations]
#       __pyx_t_1 = ((PyObject_AsWriteBuffer(__pyx_v_dist, (&__pyx_v_distdat), (&__pyx_v_buflend)) != 0) != 0);
#                     ^
#     /usr/local/Cellar/python/3.7.0/Frameworks/Python.framework/Versions/3.7/include/python3.7m/abstract.h:503:40: note: 'PyObject_AsWriteBuffer' has been explicitly marked deprecated here
#                                            Py_DEPRECATED(3.0);
#                                            ^
#     /usr/local/Cellar/python/3.7.0/Frameworks/Python.framework/Versions/3.7/include/python3.7m/pyport.h:493:54: note: expanded from macro 'Py_DEPRECATED'
#     #define Py_DEPRECATED(VERSION_UNUSED) __attribute__((__deprecated__))
#                                                          ^
#     _proj.c:5065:17: warning: 'PyObject_AsWriteBuffer' is deprecated [-Wdeprecated-declarations]
#       __pyx_t_1 = ((PyObject_AsWriteBuffer(__pyx_v_lons1, (&__pyx_v_londata), (&__pyx_v_buflenlons)) != 0) != 0);
#                     ^
#     /usr/local/Cellar/python/3.7.0/Frameworks/Python.framework/Versions/3.7/include/python3.7m/abstract.h:503:40: note: 'PyObject_AsWriteBuffer' has been explicitly marked deprecated here
#                                            Py_DEPRECATED(3.0);
#                                            ^
#     /usr/local/Cellar/python/3.7.0/Frameworks/Python.framework/Versions/3.7/include/python3.7m/pyport.h:493:54: note: expanded from macro 'Py_DEPRECATED'
#     #define Py_DEPRECATED(VERSION_UNUSED) __attribute__((__deprecated__))
#                                                          ^
#     _proj.c:5094:17: warning: 'PyObject_AsWriteBuffer' is deprecated [-Wdeprecated-declarations]
#       __pyx_t_1 = ((PyObject_AsWriteBuffer(__pyx_v_lats1, (&__pyx_v_latdata), (&__pyx_v_buflenlats)) != 0) != 0);
#                     ^
#     /usr/local/Cellar/python/3.7.0/Frameworks/Python.framework/Versions/3.7/include/python3.7m/abstract.h:503:40: note: 'PyObject_AsWriteBuffer' has been explicitly marked deprecated here
#                                            Py_DEPRECATED(3.0);
#                                            ^
#     /usr/local/Cellar/python/3.7.0/Frameworks/Python.framework/Versions/3.7/include/python3.7m/pyport.h:493:54: note: expanded from macro 'Py_DEPRECATED'
#     #define Py_DEPRECATED(VERSION_UNUSED) __attribute__((__deprecated__))
#                                                          ^
#     _proj.c:5123:17: warning: 'PyObject_AsWriteBuffer' is deprecated [-Wdeprecated-declarations]
#       __pyx_t_1 = ((PyObject_AsWriteBuffer(__pyx_v_lons2, (&__pyx_v_azdat), (&__pyx_v_buflenaz)) != 0) != 0);
#                     ^
#     /usr/local/Cellar/python/3.7.0/Frameworks/Python.framework/Versions/3.7/include/python3.7m/abstract.h:503:40: note: 'PyObject_AsWriteBuffer' has been explicitly marked deprecated here
#                                            Py_DEPRECATED(3.0);
#                                            ^
#     /usr/local/Cellar/python/3.7.0/Frameworks/Python.framework/Versions/3.7/include/python3.7m/pyport.h:493:54: note: expanded from macro 'Py_DEPRECATED'
#     #define Py_DEPRECATED(VERSION_UNUSED) __attribute__((__deprecated__))
#                                                          ^
#     _proj.c:5152:17: warning: 'PyObject_AsWriteBuffer' is deprecated [-Wdeprecated-declarations]
#       __pyx_t_1 = ((PyObject_AsWriteBuffer(__pyx_v_lats2, (&__pyx_v_distdat), (&__pyx_v_buflend)) != 0) != 0);
#                     ^
#     /usr/local/Cellar/python/3.7.0/Frameworks/Python.framework/Versions/3.7/include/python3.7m/abstract.h:503:40: note: 'PyObject_AsWriteBuffer' has been explicitly marked deprecated here
#                                            Py_DEPRECATED(3.0);
#                                            ^
#     /usr/local/Cellar/python/3.7.0/Frameworks/Python.framework/Versions/3.7/include/python3.7m/pyport.h:493:54: note: expanded from macro 'Py_DEPRECATED'
#     #define Py_DEPRECATED(VERSION_UNUSED) __attribute__((__deprecated__))
#                                                          ^
#     _proj.c:7421:21: error: no member named 'exc_type' in 'struct _ts'
#         *type = tstate->exc_type;
#                 ~~~~~~  ^
#     _proj.c:7422:22: error: no member named 'exc_value' in 'struct _ts'; did you mean 'curexc_value'?
#         *value = tstate->exc_value;
#                          ^~~~~~~~~
#                          curexc_value
#     /usr/local/Cellar/python/3.7.0/Frameworks/Python.framework/Versions/3.7/include/python3.7m/pystate.h:237:15: note: 'curexc_value' declared here
#         PyObject *curexc_value;
#                   ^
#     _proj.c:7423:19: error: no member named 'exc_traceback' in 'struct _ts'; did you mean 'curexc_traceback'?
#         *tb = tstate->exc_traceback;
#                       ^~~~~~~~~~~~~
#                       curexc_traceback
#     /usr/local/Cellar/python/3.7.0/Frameworks/Python.framework/Versions/3.7/include/python3.7m/pystate.h:238:15: note: 'curexc_traceback' declared here
#         PyObject *curexc_traceback;
#                   ^
#     _proj.c:7435:24: error: no member named 'exc_type' in 'struct _ts'
#         tmp_type = tstate->exc_type;
#                    ~~~~~~  ^
#     _proj.c:7436:25: error: no member named 'exc_value' in 'struct _ts'; did you mean 'curexc_value'?
#         tmp_value = tstate->exc_value;
#                             ^~~~~~~~~
#                             curexc_value
#     /usr/local/Cellar/python/3.7.0/Frameworks/Python.framework/Versions/3.7/include/python3.7m/pystate.h:237:15: note: 'curexc_value' declared here
#         PyObject *curexc_value;
#                   ^
#     _proj.c:7437:22: error: no member named 'exc_traceback' in 'struct _ts'; did you mean 'curexc_traceback'?
#         tmp_tb = tstate->exc_traceback;
#                          ^~~~~~~~~~~~~
#                          curexc_traceback
#     /usr/local/Cellar/python/3.7.0/Frameworks/Python.framework/Versions/3.7/include/python3.7m/pystate.h:238:15: note: 'curexc_traceback' declared here
#         PyObject *curexc_traceback;
#                   ^
#     _proj.c:7438:13: error: no member named 'exc_type' in 'struct _ts'
#         tstate->exc_type = type;
#         ~~~~~~  ^
#     _proj.c:7439:13: error: no member named 'exc_value' in 'struct _ts'; did you mean 'curexc_value'?
#         tstate->exc_value = value;
#                 ^~~~~~~~~
#                 curexc_value
#     /usr/local/Cellar/python/3.7.0/Frameworks/Python.framework/Versions/3.7/include/python3.7m/pystate.h:237:15: note: 'curexc_value' declared here
#         PyObject *curexc_value;
#                   ^
#     _proj.c:7440:13: error: no member named 'exc_traceback' in 'struct _ts'; did you mean 'curexc_traceback'?
#         tstate->exc_traceback = tb;
#                 ^~~~~~~~~~~~~
#                 curexc_traceback
#     /usr/local/Cellar/python/3.7.0/Frameworks/Python.framework/Versions/3.7/include/python3.7m/pystate.h:238:15: note: 'curexc_traceback' declared here
#         PyObject *curexc_traceback;
#                   ^
#     _proj.c:7483:24: error: no member named 'exc_type' in 'struct _ts'
#         tmp_type = tstate->exc_type;
#                    ~~~~~~  ^
#     _proj.c:7484:25: error: no member named 'exc_value' in 'struct _ts'; did you mean 'curexc_value'?
#         tmp_value = tstate->exc_value;
#                             ^~~~~~~~~
#                             curexc_value
#     /usr/local/Cellar/python/3.7.0/Frameworks/Python.framework/Versions/3.7/include/python3.7m/pystate.h:237:15: note: 'curexc_value' declared here
#         PyObject *curexc_value;
#                   ^
#     _proj.c:7485:22: error: no member named 'exc_traceback' in 'struct _ts'; did you mean 'curexc_traceback'?
#         tmp_tb = tstate->exc_traceback;
#                          ^~~~~~~~~~~~~
#                          curexc_traceback
#     /usr/local/Cellar/python/3.7.0/Frameworks/Python.framework/Versions/3.7/include/python3.7m/pystate.h:238:15: note: 'curexc_traceback' declared here
#         PyObject *curexc_traceback;
#                   ^
#     _proj.c:7486:13: error: no member named 'exc_type' in 'struct _ts'
#         tstate->exc_type = local_type;
#         ~~~~~~  ^
#     _proj.c:7487:13: error: no member named 'exc_value' in 'struct _ts'; did you mean 'curexc_value'?
#         tstate->exc_value = local_value;
#                 ^~~~~~~~~
#                 curexc_value
#     /usr/local/Cellar/python/3.7.0/Frameworks/Python.framework/Versions/3.7/include/python3.7m/pystate.h:237:15: note: 'curexc_value' declared here
#         PyObject *curexc_value;
#                   ^
#     _proj.c:7488:13: error: no member named 'exc_traceback' in 'struct _ts'; did you mean 'curexc_traceback'?
#         tstate->exc_traceback = local_tb;
#                 ^~~~~~~~~~~~~
#                 curexc_traceback
#     /usr/local/Cellar/python/3.7.0/Frameworks/Python.framework/Versions/3.7/include/python3.7m/pystate.h:238:15: note: 'curexc_traceback' declared here
#         PyObject *curexc_traceback;
#                   ^
#     15 warnings and 15 errors generated.
#     error: command 'clang' failed with exit status 1
#
#     ----------------------------------------
# Command "/Users/chao/venv/bin/python3.7 -u -c "import setuptools, tokenize;__file__='/private/var/folders/h3/mrhx5cg11xn7w4yzstp8sx7w0000gn/T/pip-install-a07gnxom/pyproj/setup.py';f=getattr(tokenize, 'open', open)(__file__);code=f.read().replace('\r\n', '\n');f.close();exec(compile(code, __file__, 'exec'))" install --record /private/var/folders/h3/mrhx5cg11xn7w4yzstp8sx7w0000gn/T/pip-record-78e6_rol/install-record.txt --single-version-externally-managed --compile --install-headers /Users/chao/venv/include/site/python3.7/pyproj" failed with error code 1 in /private/var/folders/h3/mrhx5cg11xn7w4yzstp8sx7w0000gn/T/pip-install-a07gnxom/pyproj/

# %%
# !pip install git+https://github.com/jswhit/pyproj.git
# Out:
# Collecting git+https://github.com/jswhit/pyproj.git
#   Cloning https://github.com/jswhit/pyproj.git to /private/var/folders/h3/mrhx5cg11xn7w4yzstp8sx7w0000gn/T/pip-req-build-dpe054sp
# Installing collected packages: pyproj
#   Running setup.py install for pyproj ... done
# Successfully installed pyproj-1.9.5.1

# %%
# !pip install cython
# Out:
# Collecting cython
#   Downloading https://files.pythonhosted.org/packages/3a/ad/836782c4d860bf8099d94e76a551c2d69cf516c790c4b4c01e394fa6b379/Cython-0.29-cp37-cp37m-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl (2.9MB)
#     100% |████████████████████████████████| 2.9MB 1.3MB/s ta 0:00:01
# Installing collected packages: cython
# Successfully installed cython-0.29

# %%
import pandas as pd
df_selected_jobs = pd.read_csv("0 jobs.csv")
list1=[]
dict1={}
for i in df_selected_jobs["Location"]:
    try: 
        list1.append(i.split(', ')[1][:2])
    except:
        pass
for i in list1:
    dict1[i]=list1.count(i)
code=list(dict1.keys())
value=list(dict1.values())

# %%
import plotly.plotly as py
import pandas as pd

df_selected_jobs = pd.read_csv("reference/0 jobs.csv")
list1=[]
dict1={}
for i in df_selected_jobs["Location"]:
    try: 
        list1.append(i.split(', ')[1][:2])
    except:
        pass
for i in list1:
    dict1[i]=list1.count(i)
code=list(dict1.keys())
value=list(dict1.values())

for col in df.columns:
    df[col] = df[col].astype(str)

scl = [[0.0, 'rgb(242,240,247)'],[0.2, 'rgb(218,218,235)'],[0.4, 'rgb(188,189,220)'],\
            [0.6, 'rgb(158,154,200)'],[0.8, 'rgb(117,107,177)'],[1.0, 'rgb(84,39,143)']]


data = [ dict(
        type='choropleth',
        colorscale = scl,
        autocolorscale = False,
        locations = code,
        z = value,
        locationmode = 'USA-states',
        text = code,
        marker = dict(
            line = dict (
                color = 'rgb(255,255,255)',
                width = 2
            ) ),
        colorbar = dict(
            title = "how many positions")
        ) ]

layout = dict(
        title = 'U.S journalism jobs',
        geo = dict(
            scope='usa',
            projection=dict( type='albers usa' ),
            showlakes = True,
            lakecolor = 'rgb(255, 255, 255)'),
             )
    
fig = dict( data=data, layout=layout )
py.iplot( fig, filename='d3-cloropleth-map' )
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-d7f2586c4b92> in <module>()
#       2 import pandas as pd
#       3
# ----> 4 df_selected_jobs = pd.read_csv("reference/0 jobs.csv")
#       5 list1=[]
#       6 dict1={}
#
# ~/venv/lib/python3.7/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, doublequote, delim_whitespace, low_memory, memory_map, float_precision)
#     676                     skip_blank_lines=skip_blank_lines)
#     677
# --> 678         return _read(filepath_or_buffer, kwds)
#     679
#     680     parser_f.__name__ = name
#
# ~/venv/lib/python3.7/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     438
#     439     # Create the parser.
# --> 440     parser = TextFileReader(filepath_or_buffer, **kwds)
#     441
#     442     if chunksize or iterator:
#
# ~/venv/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     785             self.options['has_index_names'] = kwds['has_index_names']
#     786
# --> 787         self._make_engine(self.engine)
#     788
#     789     def close(self):
#
# ~/venv/lib/python3.7/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1012     def _make_engine(self, engine='c'):
#    1013         if engine == 'c':
# -> 1014             self._engine = CParserWrapper(self.f, **self.options)
#    1015         else:
#    1016             if engine == 'python':
#
# ~/venv/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1706         kwds['usecols'] = self.usecols
#    1707
# -> 1708         self._reader = parsers.TextReader(src, **kwds)
#    1709
#    1710         passed_names = self.names is None
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: File b'reference/0 jobs.csv' does not exist
